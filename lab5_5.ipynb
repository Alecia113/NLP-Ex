# %% [markdown]
# <a href="https://colab.research.google.com/github/Alecia113/NLP-Ex/blob/main/lab5_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
#You can enable GPU here (cuda); or just CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Code to download file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

id = '1gNfBqguzBu8cHKMPc8C44GbvD443dNC5'
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('twitter.csv')  

import pandas as pd
df = pd.read_csv("twitter.csv")
df_pick = df.sample(400,random_state=24)

raw_text = df_pick["Text"].tolist()
raw_label = df_pick["Label"].tolist()

from sklearn.model_selection import train_test_split
text_train,text_test,label_train,label_test = train_test_split(raw_text,raw_label,test_size=0.25,random_state=42)

# %%
text_train = [s.lower() for s in text_train]
text_test = [s.lower() for s in text_test]

# %%
import re
def remove_punctuation_re(x):
    # Please complete this
    x = re.sub(r'[^\w\s]','',x)
    return x
    
text_train = [remove_punctuation_re(s) for s in text_train]
text_test = [remove_punctuation_re(s) for s in text_test]

# %%
import nltk
nltk.download('punkt')
import pprint
from nltk.tokenize import word_tokenize

train_t=[]
for s in text_train:
  text_train = word_tokenize(s)                         #每句话分别作了分词 text_train[0]第一句话的分词
  train_t.append(text_train)  
pprint.pprint(train_t[:10])             #目前是300 #[['finalbroadcast', 'or', 'many', 'dkim', 'setups', 'for', 'that', 'matter'],

test_t=[]
for w in text_test:
  text_test = word_tokenize(w)
  test_t.append(text_test)
#pprint.pprint(text_test[1:3])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [['finalbroadcast', 'or', 'many', 'dkim', 'setups', 'for', 'that', 'matter'],
#  ['sevilzadeh',
#   'mohammed',
#   'led',
#   '17',
#   'major',
#   'military',
#   'expeditions',
#   'most',
#   'offensive',
#   'he',
#   'raped',
#   'robbed',
#   'murdered',
#   'lied',
#   'slaved',
#   'and',
#   'was',
#   'a',
#   'pedophile'],
#  ['benkuchera', 'i', 'saw', 'your', 'face'],
#  ['realryansipple',
#   'a',
#   'real',
#   'attack',
#   'on',
#   'al',
#   'asad',
#   'would',
#   'yield',
#   'a',
#   'daesh',
#   'killing',
#   'ground',
#   'lots',
#   'of',
#   'open',
#   'space',
#   'and',
#   'no',
#   'civilians',
#   'to',
#   'hide',
#   'behind'],
#  ['can',
#   'someone',
#   'explain',
#   'to',
#   'the',
#   'gals',
#   'sass',
#   'is',
#   'not',
#   'the',
#   'same',
#   'as',
#   'edible',
#   'food',
#   'mkr'],
#  ['rt',
#   'channel7',
#   'british',
#   'lads',
#   'will',
#   'and',
#   'steve',
#   'are',
#   'taking',
#   'on',
#   'the',
#   'mykitchenrules',
#   'instant',
#   'restaurant',
#   'tonight',
#   'and',
#   'theyre',
#   'on',
#   'now',
#   'mkr',
#   'httptco'],
#  ['can',
#   'not',
#   'believe',
#   'those',
#   'two',
#   'fucktards',
#   'are',
#   'still',
#   'in',
#   'the',
#   'competition',
#   'my',
#   'middle',
#   'finger',
#   'says',
#   'hello',
#   'to',
#   'you',
#   'kat',
#   'amp',
#   'andre',
#   'assholes',
#   'mkr'],
#  ['i',
#   'hope',
#   'this',
#   'instant',
#   'restaurant',
#   'round',
#   'is',
#   'a',
#   'good',
#   'one',
#   'getting',
#   'a',
#   'bit',
#   'over',
#   'them',
#   'mkr',
#   'mkr2015'],
#  ['dankmtl',
#   'peacenothate_',
#   'yeah',
#   'keep',
#   'celebrating',
#   'while',
#   'you',
#   'look',
#   'like',
#   'a',
#   'cretin',
#   'httptcotfsodcowbx'],
#  ['lithobolos',
#   'politicalant',
#   'zaibatsunews',
#   'what',
#   'double',
#   'standard',
#   'microbrain',
#   'im',
#   'not',
#   'a',
#   'jew',
#   'or',
#   'a',
#   'christian']]

# %%
text_train
# Out:
# ['haroonstyles',
#  'greenlinerzjm',
#  'halalflaws',
#  'biebervalue',
#  'show',
#  'me',
#  'the',
#  'hadith',
#  'where',
#  'you',
#  'get',
#  'your',
#  'information',
#  'im',
#  'waiting']

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords as sw
stop_words = sw.words()

text_train_ns=[]
for tokens in train_t:
    filtered_sentence1 = [w for w in tokens if not w in stop_words]
    text_train_ns.append(filtered_sentence1)

text_test_ns=[]
for tokens in test_t:
  filtered_sentence2 = [w for w in tokens if not w in stop_words]
  text_test_ns.append(filtered_sentence2)
    #Please complete this
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pprint.pprint(text_train_ns)
# Out:
# [['finalbroadcast', 'many', 'dkim', 'setups', 'matter'],
#  ['sevilzadeh',
#   'mohammed',
#   'led',
#   '17',
#   'major',
#   'military',
#   'expeditions',
#   'offensive',
#   'raped',
#   'robbed',
#   'murdered',
#   'lied',
#   'slaved',
#   'pedophile'],
#  ['benkuchera', 'saw'],
#  ['realryansipple',
#   'real',
#   'attack',
#   'asad',
#   'would',
#   'yield',
#   'daesh',
#   'killing',
#   'ground',
#   'lots',
#   'open',
#   'space',
#   'civilians',
#   'hide',
#   'behind'],
#  ['someone', 'explain', 'gals', 'sass', 'edible', 'food', 'mkr'],
#  ['rt',
#   'channel7',
#   'british',
#   'lads',
#   'steve',
#   'taking',
#   'mykitchenrules',
#   'instant',
#   'restaurant',
#   'tonight',
#   'theyre',
#   'mkr',
#   'httptco'],
#  ['believe',
#   'two',
#   'fucktards',
#   'still',
#   'competition',
#   'middle',
#   'finger',
#   'says',
#   'hello',
#   'kat',
#   'amp',
#   'andre',
#   'assholes',
#   'mkr'],
#  ['hope',
#   'instant',
#   'restaurant',
#   'round',
#   'good',
#   'getting',
#   'bit',
#   'mkr',
#   'mkr2015'],
#  ['dankmtl',
#   'peacenothate_',
#   'yeah',
#   'keep',
#   'celebrating',
#   'look',
#   'like',
#   'cretin',
#   'httptcotfsodcowbx'],
#  ['lithobolos',
#   'politicalant',
#   'zaibatsunews',
#   'double',
#   'standard',
#   'microbrain',
#   'jew',
#   'christian'],
#  ['thinking',
#   'daesh',
#   'choice',
#   'try',
#   'back',
#   'intersection',
#   'hw',
#   '1',
#   'hw',
#   '47',
#   'near',
#   'tal',
#   'afar'],
#  ['mikeage', 'isnt', 'p'],
#  ['planning',
#   'stopping',
#   'portland',
#   'dont',
#   'think',
#   'going',
#   'time',
#   'much',
#   'get',
#   'back'],
#  ['directhex', 'httptcocaxxus108l'],
#  ['colins', 'serving', 'mkr'],
#  ['rt',
#   'dubhe80',
#   'maja_stina',
#   'raised',
#   'women',
#   'majority',
#   'coworkers',
#   'r',
#   'womeninterpret',
#   'words',
#   'wish',
#   'matter',
#   'much',
#   'twist'],
#  ['rt', 'tatibresolin', 'oh', 'colin', 'washed', 'hair', 'mkr'],
#  ['maxblumenthal',
#   'mehdirhasan',
#   'tnr',
#   'imagine',
#   'muslim',
#   'journalist',
#   'making',
#   'case',
#   'isis',
#   'islamic',
#   'self',
#   'interest',
#   'lol'],
#  ['watch',
#   'tarts',
#   'poorly',
#   'constructed',
#   'personalities',
#   'deconstruct',
#   'tart',
#   'mkr'],
#  ['johnnyrejection',
#   'espn',
#   'yeah',
#   'never',
#   'comment',
#   'athletes',
#   'bodies',
#   'ever'],
#  ['cooking',
#   'ears',
#   'cityofmandurah',
#   'thegoodguysau',
#   'crabfest15',
#   'mkr',
#   'chloeandkelly',
#   'httpstco6kgw1lejfr'],
#  ['rt',
#   'rkhayer',
#   'kurdish',
#   'troops',
#   'liberate',
#   'kirkuk',
#   'oil',
#   'workers',
#   'sputnik',
#   'international',
#   'iraq',
#   'kurds',
#   'isis',
#   'hostages',
#   'prisonersofwar',
#   'httpt'],
#  ['rayyoosheh', 'call', 'httptcomxuw3hz4tb'],
#  ['uplay', 'launcher', 'crashes', 'repeatedly'],
#  ['rt',
#   'victorymonk',
#   'womenagainstfeminism',
#   'dont',
#   'know',
#   'httpstcoum5svjgazu'],
#  ['darrenkopp', 'bsilverstrim77', 'already', 'bought'],
#  ['important',
#   'note',
#   'stats',
#   'taken',
#   'large',
#   'timespan',
#   'past',
#   '12',
#   'typically',
#   'slow',
#   'time'],
#  ['mkr', 'oh', 'nooo', 'goodluck', 'yall'],
#  ['wetsprocket',
#   'didnt',
#   'read',
#   'p',
#   'sent',
#   'screencaps',
#   'bit',
#   'concerned'],
#  ['wow', 'see', 'coming', 'mkr'],
#  ['rt',
#   'fyoudbag',
#   'insulting',
#   'women',
#   'expect',
#   'attracted',
#   'super',
#   'easy',
#   'games',
#   'honestly',
#   'insulted',
#   'parent',
#   'girl'],
#  ['fuck', 'show', 'still', 'running', 'christmas', 'mkr'],
#  ['mistertodd',
#   'hoping',
#   'well',
#   'able',
#   'release',
#   'info',
#   'soon',
#   'lots',
#   'stuff',
#   'works',
#   'promise',
#   'big',
#   'things'],
#  ['rt',
#   'angelemichelle',
#   'rt',
#   'phxken',
#   'islam',
#   'contributing',
#   'damn',
#   'thing',
#   'humanity',
#   '1400',
#   'years',
#   'httptcodajgdn1wy3',
#   'well',
#   'except',
#   'murde'],
#  ['may',
#   'business',
#   'saudis',
#   'dont',
#   'pretend',
#   'anything',
#   'backwards',
#   'islamic',
#   'dictatorship',
#   'islam'],
#  ['confuse', 'good', 'way', 'mkr', 'httptcouq19q6pnaq'],
#  ['seriously',
#   'two',
#   'couples',
#   'could',
#   'actually',
#   'cook',
#   'gone',
#   'two',
#   'others',
#   'clearly',
#   'even',
#   'show',
#   'reputations',
#   'ruins',
#   'mkr'],
#  ['rt', 'cjsajulga', 'women', 'reckless', 'drivers', 'notsexist', 'realtalk'],
#  ['goosenetworkusa',
#   '06jank',
#   'patrickosgood',
#   'tweets',
#   'shred',
#   'evidence',
#   'blocked'],
#  ['promo',
#   'girls',
#   'promo',
#   'gloves',
#   'gumboots',
#   '3outof10',
#   'mkr',
#   'mkr2015'],
#  ['mkr', 'would', 'anyone', 'eat', 'chicken', 'liver', 'thats', 'ew'],
#  ['really',
#   'fan',
#   'katieandnikki',
#   'wouldve',
#   'rather',
#   'stayed',
#   'katandandre',
#   'mkr'],
#  ['rt', '2ndbestidiot', 'kat', 'nasty', 'piece', 'work', 'tbh', 'mkr'],
#  ['rt',
#   'masontillidie',
#   'wizardryofozil',
#   'deusexjuice',
#   'yesyouresexist',
#   'people',
#   'damn',
#   'sensitive',
#   'lol'],
#  ['kat',
#   'feel',
#   'like',
#   'dream',
#   'yeah',
#   'dreamer',
#   'absolutely',
#   'cooking',
#   'ability',
#   'mkr'],
#  ['rt',
#   'schmeezi',
#   'reminded',
#   'harshly',
#   'women',
#   'boss',
#   'truly',
#   'sucks',
#   'sorrynotsorry',
#   'itsfact',
#   'notsexist'],
#  ['rt',
#   'bronny25',
#   'katampandre',
#   'monday',
#   'people',
#   'voted',
#   'strategically',
#   'rude',
#   'katampandre',
#   'tonight',
#   'votes',
#   'strategically',
#   'third',
#   'time'],
#  ['floss',
#   'weekly',
#   'open',
#   'source',
#   'projects',
#   'paying',
#   'bills',
#   'httptcoqmdsdtfvya'],
#  ['rt',
#   'itsbariecool',
#   'mccheesy904',
#   'happens',
#   'vice',
#   'versa',
#   'smarter',
#   'naturally',
#   'notsexist'],
#  ['kat',
#   'amp',
#   'andre',
#   'hated',
#   'mkr',
#   'team',
#   'australia',
#   'revolting',
#   'couple',
#   'mkr2015'],
#  ['toodles', 'bitches', 'mkr'],
#  ['psychbarakat',
#   'jncatron',
#   'told',
#   'idiot',
#   'go',
#   'look',
#   'origin',
#   'anti',
#   'semite',
#   'meaning'],
#  ['new_babylonia',
#   'propaganda',
#   'shia',
#   'militia',
#   'religious',
#   'fanatics',
#   'fascists',
#   'like',
#   'isis',
#   'slightly',
#   'less',
#   'extreme'],
#  ['nscottg',
#   'small',
#   'org',
#   'works',
#   'amazingly',
#   'well',
#   'everything',
#   'configuration',
#   'love',
#   'vcs',
#   'integrations'],
#  ['politicalant',
#   'zene55',
#   'bq281473',
#   'foxnewspolitics',
#   'barackobama',
#   'difference',
#   'isis',
#   'mohammed'],
#  ['rt',
#   'serlasco',
#   'need',
#   'girl',
#   'thatll',
#   'iron',
#   'shirts',
#   'call',
#   'sexist'],
#  ['mattstratton',
#   'magnus919',
#   'theckman',
#   'cheeseplus',
#   'tbielawa',
#   'markimbriaco',
#   'talk',
#   'bringing',
#   'tweets',
#   'back',
#   'dead'],
#  ['buttercupashby',
#   'madasahatter_17',
#   'lie',
#   'majority',
#   'muslims',
#   'forced',
#   'httptcoumkitlb5h9'],
#  ['number',
#   'emails',
#   'attributing',
#   'rts',
#   'wocracial',
#   'issues',
#   'spoiled',
#   'white',
#   'girl',
#   'guilt',
#   'greater',
#   '0'],
#  ['dankmtl',
#   'idiot',
#   'none',
#   'changes',
#   'ratio',
#   'muslims',
#   'christians',
#   'palestine',
#   'muslim',
#   'bigotry',
#   'abuse',
#   'changes'],
#  ['colin', 'pretty', 'nice', 'girls', 'think', 'hes', 'giving', 'dick', 'mkr'],
#  ['reza_rahman',
#   'basically',
#   'claiming',
#   'religion',
#   'teaches',
#   'hatred',
#   'murder',
#   'nothing',
#   'hatred',
#   'murder',
#   'dumb'],
#  ['maxblumenthal',
#   'mami_mermelada',
#   'grahamdavida',
#   'jeffreygoldberg',
#   'hamas',
#   'however',
#   'throw',
#   'political',
#   'opponents',
#   'roof',
#   'tops'],
#  ['argh', 'cant', 'stand', 'kat', 'mkr'],
#  ['alihadi68',
#   'rudoren',
#   'nytimes',
#   'way',
#   'ask',
#   'really',
#   'consider',
#   'islam',
#   'spiritual',
#   'really'],
#  ['halalflaws',
#   'biebervalue',
#   'greenlinerzjm',
#   'prophet',
#   'never',
#   'said',
#   'countries',
#   'like',
#   'pakistan',
#   '90',
#   'domestic',
#   'violence',
#   'rate'],
#  ['rt',
#   'anitaingle',
#   'remember',
#   'johncantile',
#   'videobeautiful',
#   'mosul',
#   'isis',
#   '2',
#   'wks',
#   'ago',
#   'well',
#   'heres',
#   'raqqa',
#   'todayreal',
#   'life',
#   'w',
#   'http'],
#  ['r', 'fucking', 'kidding', 'catwalk', 'thats', 'missing', 'pole', 'mkr'],
#  ['truaemusic',
#   'mattybboi83',
#   'number10gov',
#   'child',
#   'abuse',
#   'illegal',
#   'western',
#   'culture',
#   'accepted',
#   'islamic',
#   'cultures',
#   'prophet'],
#  ['rt',
#   'lajouetreine',
#   'obamas',
#   'moderate',
#   'rebels',
#   'burning',
#   'christiansyazidis',
#   'amp',
#   'muslims',
#   'alive',
#   'ccot',
#   'pjnet',
#   'syria',
#   'egypt',
#   'libya',
#   'iraq',
#   'httptco4u'],
#  ['randomhero30',
#   'rooshv',
#   'minasmith64',
#   'get',
#   'rotherham',
#   'redux',
#   'raped',
#   'cytheria'],
#  ['rt',
#   'victorymonk',
#   'woman',
#   'rips',
#   'mans',
#   'testicle',
#   'rejected',
#   'tried',
#   'swallow',
#   'httptcospmvzcjj6o',
#   'questionsformen',
#   'askgoog'],
#  ['kat', 'awful', 'bitch', 'mkr'],
#  ['jac', 'shaz', 'peopleschoice', 'mkr', 'happycampers'],
#  ['hdmovieus',
#   'islam',
#   'terror',
#   'fight',
#   'terror',
#   'fight',
#   'islam',
#   'prophet',
#   'god',
#   'sick',
#   'terrorists',
#   'islam'],
#  ['rt',
#   'maajidnawaz',
#   'ggreenwald',
#   'teaching',
#   'discrimination',
#   'implies',
#   'via',
#   'link',
#   'critiquing',
#   'islam',
#   'like',
#   'homophobe',
#   'http'],
#  ['seriously', 'kat', 'tasteless', 'youre', 'grown', 'woman', 'mkr'],
#  ['rt',
#   'mellym09',
#   'really',
#   'fan',
#   'katieandnikki',
#   'wouldve',
#   'rather',
#   'stayed',
#   'katandandre',
#   'mkr'],
#  ['rt',
#   'aledthomas22',
#   'sexist',
#   'stand',
#   'watching',
#   'sport',
#   'women',
#   'question',
#   'question',
#   'question'],
#  ['eloisepeace',
#   'agree',
#   'lose',
#   'interest',
#   'instant',
#   'restaurants',
#   'think',
#   'theyre',
#   'cashing',
#   'fact',
#   'year',
#   'mkr'],
#  ['rt',
#   'davidsgallant',
#   'freebsdgirl',
#   'call',
#   'd20',
#   'cuz',
#   'even',
#   'knows',
#   'youre',
#   'gon',
#   'roll'],
#  ['dont',
#   'see',
#   'pilots',
#   'license',
#   'rennie93',
#   'females',
#   'struggle',
#   'driving',
#   'cars',
#   'yet',
#   'flying',
#   'plane',
#   'notsexist',
#   'justhonest'],
#  ['channel7',
#   'hows',
#   'colin',
#   'rounds',
#   'working',
#   'pretty',
#   'crap',
#   'id',
#   'say',
#   'tweets',
#   'needarethinkinformat',
#   'mkr'],
#  ['meatgirls',
#   'bamboozled',
#   'opener',
#   'sorbet',
#   'churner',
#   'promogirls',
#   'danis',
#   'direct',
#   'mkr'],
#  ['peerworker',
#   'yes',
#   'given',
#   'group',
#   'routinely',
#   'posts',
#   'mutilated',
#   'bodies',
#   'twitter',
#   'along',
#   'american',
#   'passports',
#   'id',
#   'say',
#   'worse'],
#  ['thedoubleclicks', 'make', 'drive', 'tempting', 'p'],
#  ['rt',
#   'mugnezee',
#   'sexist',
#   'watching',
#   'girls',
#   'ice',
#   'hockey',
#   'really',
#   'painful'],
#  ['fun',
#   'watching',
#   'gg',
#   'trying',
#   'make',
#   'us',
#   'fight',
#   'quit',
#   'trying',
#   'make',
#   'fetch',
#   'happen',
#   'never',
#   'going',
#   'happen',
#   'spacekatgal',
#   'thequinnspiracy'],
#  ['rennie93', 'wow', 'excuses', 'sexism'],
#  ['two', 'blondes', 'beavis', 'butthead', 'mkr'],
#  ['wow',
#   'wasnt',
#   'stiff',
#   'scripted',
#   'witty',
#   'banter',
#   'real',
#   'chefs',
#   'mkr'],
#  ['slagkick', 'oh', 'yeah', 'spam', 'hell', 'buttons'],
#  ['rt', 'budlightbro', 'fuck', 'sexist', 'girl', 'recruit', 'school', 'bitch'],
#  ['vandaliser',
#   'sajid_fairooz',
#   'israeliregime',
#   'even',
#   'hitler',
#   'jews',
#   'still',
#   'live',
#   'west',
#   'hatefilled',
#   'islam'],
#  ['oh', 'god', 'httptcowhy3a8o33z', 'httptco5vsf5jroi6'],
#  ['pardusxy', 'ideaor', 'argument'],
#  ['notchrissmith',
#   'free',
#   'market',
#   'get',
#   'negotiate',
#   'producers',
#   'feel',
#   'fair',
#   'actoractress',
#   'accept',
#   'askhermore'],
#  ['httptcozjbwagvnrg',
#   '1shadeofritch',
#   'sexist',
#   'yesallwomen',
#   'posts',
#   'dumbest',
#   'things',
#   'twitter'],
#  ['farbenstau',
#   'xmjee',
#   'would',
#   'see',
#   'kind',
#   'stuff',
#   'youd',
#   'present',
#   'expertise',
#   'antiharassment',
#   'tools',
#   'amp',
#   'devops'],
#  ['rt',
#   'syazlicious',
#   'best',
#   'describes',
#   'kat',
#   'andre',
#   'mkr',
#   'httptcoqaa6bwi4pm'],
#  ['vex0rian', 'yes', 'recall'],
#  ['pnibbler',
#   'alternet',
#   'maxblumenthal',
#   'countries',
#   'moving',
#   'direction',
#   'muslim',
#   'ones',
#   'httptcot65iytpvdk'],
#  ['lactualaloupe', 'islam', 'race', 'microbrain'],
#  ['sumersloan',
#   'pawarnhoff',
#   'etsho127',
#   'israel',
#   'attacked',
#   'multiple',
#   'muslim',
#   'armies',
#   'multiple',
#   'occasions'],
#  ['maxblumenthal',
#   'marc_leibowitz',
#   'good',
#   'someone',
#   'finally',
#   'stood',
#   'muslim',
#   'terrorists',
#   'population',
#   'imperialism'],
#  ['politicalant',
#   'lithobolos',
#   'zaibatsunews',
#   'white',
#   'christian',
#   'hating',
#   'bigot',
#   'opposed',
#   'httptconleyqfnkyp'],
#  ['rt',
#   'maxcaras',
#   'yesyouresexist',
#   'bastendorfgames',
#   'thats',
#   'dumb',
#   'theres',
#   'nothing',
#   'wrong',
#   'satire',
#   'sexist',
#   'jokes'],
#  ['mkr', 'need', 'sleeping', 'bag', 'well', 'cause', 'show', 'boring', 'fuck'],
#  ['oh', 'well', 'back', 'promo', 'work', 'mkr', 'mkr2015'],
#  ['doammuslims',
#   'ajwatamr',
#   'scum',
#   'bag',
#   'islamists',
#   'evacuated',
#   'christian',
#   'ezidi',
#   'civilians',
#   'homes',
#   'mosul',
#   'raqqa',
#   'sinjar'],
#  ['sorry', 'changed', 'channel', 'next', 'top', 'model', 'mkr'],
#  ['rt', 'robinriedstra', 'nobody', 'likes', 'dry', 'sausage', 'mkr'],
#  ['tobyrobertbull',
#   'pretty',
#   'sure',
#   'dudes',
#   'constantly',
#   'pissing',
#   'public'],
#  ['explain',
#   'doctor',
#   'optional',
#   'surgery',
#   'planning',
#   'cant',
#   'happen',
#   'next',
#   'months',
#   'bcz',
#   'time',
#   'recuperate'],
#  ['anasmechch',
#   'peymaneh123',
#   'group',
#   'behaving',
#   'somewhat',
#   'reasonably',
#   'kurdish',
#   'forces'],
#  ['bahai144',
#   'believe',
#   'isis',
#   'attacked',
#   'believe',
#   'attacked',
#   'clarify',
#   'record',
#   'right'],
#  ['celine', 'mkr', 'httptcobwr6ap0ooo'],
#  ['rt',
#   'ezidipress',
#   'narîn',
#   'young',
#   'ezidi',
#   'women',
#   'shingal',
#   'abducted',
#   'enslaved',
#   'sold',
#   'raped',
#   'isis',
#   'terrorists',
#   'committed',
#   'suicide'],
#  ['pretty',
#   'adjective',
#   '1',
#   'attractive',
#   'delicate',
#   'way',
#   'without',
#   'truly',
#   'beautifula',
#   'pretty',
#   'little',
#   'girl',
#   'engaging',
#   'grin',
#   'mkr'],
#  ['rt',
#   'brushyblues',
#   'juliet777777',
#   'youtube',
#   'disturbing',
#   'new',
#   'isis',
#   'video',
#   'buying',
#   'selling',
#   'female',
#   'sex',
#   'slaves',
#   'httptcorbthvmh9jj',
#   'makes'],
#  ['rt', 'rinehart33', 'sexist', 'women', 'drivers', 'terrible'],
#  ['shermertron',
#   'humanistfury',
#   'different',
#   'standards',
#   'whiteblack',
#   'racist',
#   'equal',
#   'nope',
#   'jennykutner',
#   'salon'],
#  ['rt',
#   'lilbeastunleash',
#   'melting',
#   'didnt',
#   'put',
#   'freezer',
#   'served',
#   'dumb',
#   'skank',
#   'mkr'],
#  ['still', 'dolly', 'magazine', 'model', 'competition', 'year', 'girls', 'mkr'],
#  ['rape',
#   'punch',
#   'line',
#   'hawaiinshirts',
#   'lead',
#   'singer',
#   'maroon',
#   '5',
#   'sound',
#   'like',
#   'getting',
#   'gangraped',
#   'showers'],
#  ['dont', 'disheartened', 'emilie', 'sherri', 'mkr'],
#  ['desertfox899', 'jhamby', 'interact', 'people'],
#  ['haroonstyles',
#   'halalflaws',
#   'greenlinerzjm',
#   'biebervalue',
#   '80',
#   'muslim',
#   'civilians',
#   'killed',
#   'taliban',
#   'look'],
#  ['salon',
#   'themuslimguy',
#   'subject',
#   'islams',
#   'relationship',
#   'terrorism',
#   'comes',
#   'react',
#   'like',
#   'empty',
#   'morons'],
#  ['guess', 'kat', 'amp', 'andre', 'werent', 'hugged', 'enough', 'child', 'mkr'],
#  ['rt',
#   'colonelkickhead',
#   'someone',
#   'smash',
#   'bottle',
#   'rose',
#   'amp',
#   'lime',
#   'cordial',
#   'draskos',
#   'head',
#   'please',
#   'mkr'],
#  ['p8952_', 'grafana'],
#  ['possibly', 'respond', 'support', 'requests', 'canned', 'answers'],
#  ['amohedin',
#   'show',
#   'verse',
#   'says',
#   'forbidden',
#   'force',
#   'people',
#   'something'],
#  ['earth', 'mkr'],
#  ['haroonstyles',
#   'halalflaws',
#   'greenlinerzjm',
#   'biebervalue',
#   'yeah',
#   'cheney',
#   'burqua',
#   'selling',
#   'business'],
#  ['watan71969',
#   'total',
#   'liar',
#   'like',
#   'pedophile',
#   'prophet',
#   'soldiers',
#   'dont',
#   'burn',
#   'people',
#   'alive'],
#  ['dianh4', 'islam', 'rape', 'captive', 'women', 'hearts', 'content', 'law'],
#  ['bigtime',
#   'vc',
#   'strong',
#   'feminist',
#   'ally',
#   'leanings',
#   'curious',
#   'looking',
#   'funding'],
#  ['way',
#   'thats',
#   'sexist',
#   'abdul_a95',
#   'sexist',
#   'female',
#   'characters',
#   'tv',
#   'shows',
#   '99',
#   'usually',
#   'annoying',
#   'character'],
#  ['spacequeentbh', 'faded', 'p', 'need', 'hair', 'cut', 'dye', 'desperately'],
#  ['kamaluf', 'thats', 'easy', 'link', 'httptcomdb4iu9whd'],
#  ['httptcoltoxypkwww'],
#  ['antizholim', 'tripple', 'price', 'customers'],
#  ['slap', 'stupid', 'bimbos', 'mkr'],
#  ['saltnburnem',
#   'oreilly',
#   'books',
#   'ebooks',
#   'p',
#   'old',
#   'yes',
#   'usually',
#   'quite',
#   'like'],
#  ['rt',
#   'amymek',
#   'wakeuplibsgtjoenbc',
#   'islamic',
#   'jihadis',
#   'like',
#   'ultrafundamentalist',
#   'christians',
#   'httptcovanp6y7clr',
#   'tcot',
#   'iloveobama',
#   'httpt'],
#  ['like', 'dropped', 'pie', 'lol', 'mkr'],
#  ['arab_fury',
#   'guardian',
#   'poor',
#   'kid',
#   'wanted',
#   'grow',
#   'behead',
#   'kuffir',
#   'feel',
#   'bad',
#   'himat',
#   '14',
#   'isis',
#   'would',
#   'sent',
#   'kill'],
#  ['rt',
#   'rudawenglish',
#   'isis',
#   'executed',
#   'christian',
#   'pastor',
#   'murtaza',
#   'ablahad',
#   '44',
#   'years',
#   'old',
#   'mosul',
#   'today',
#   'isis',
#   'demanded',
#   'ransom',
#   'http'],
#  ['saifullah666', 'bs', 'story', 'others', 'claim', 'ezidis'],
#  ['mmmm',
#   'mkr',
#   'getting',
#   'boring',
#   'lisamromano',
#   'garydlum',
#   'switching',
#   'simpsons',
#   'double',
#   'ep',
#   '11',
#   'mmmm',
#   'httptcoocsy7crghf'],
#  ['kaitlynburnell', 'doh', 'haha', 'sure'],
#  ['rt',
#   'danhickey2199',
#   'mkr',
#   'killerblondes',
#   'way',
#   'girls',
#   'staying',
#   'blow',
#   'every',
#   'bloke',
#   'room',
#   'theyre',
#   'still',
#   'wi'],
#  ['offense', 'nigelbigmeech', 'sexist', 'women', 'really', 'stupid', 'offense'],
#  ['hope', 'god', 'kat', 'cant', 'sleep', 'night', 'mkr'],
#  ['rt',
#   'allstatejackie',
#   'antis',
#   'stop',
#   'treating',
#   'blocks',
#   'trophies',
#   'soon',
#   'feminists',
#   'stop',
#   'treating',
#   'blocks',
#   'arguments',
#   'gamergate'],
#  ['nader_haq', 'maddr11', 'maxblumenthal', 'httptcoddecobanzx'],
#  ['definitely', 'rigged', 'mkr'],
#  ['things',
#   'scared',
#   'whiny',
#   'manbabies',
#   'lot',
#   'twitter',
#   'mentions',
#   'public',
#   'speaking',
#   'perl',
#   'standing',
#   'afraid',
#   'feels'],
#  ['writing', 'bimbolines', 'mkr'],
#  ['yeah', 'colin', 'would', 'looking', 'fat', 'sausage', 'mkr'],
#  ['flips', 'desks', 'mkr'],
#  ['rt',
#   'psogeco',
#   'little',
#   'short',
#   'point',
#   'islam',
#   'lessons',
#   'us',
#   'ignorant',
#   'httptcom4jcka5ir0',
#   'httptcoganrh4k87a',
#   'via',
#   'psog'],
#  ['swiftonsecurity', 'jeremiahfelt', 'gross'],
#  ['freebsdglri', 'awww', 'someones', 'mad', 'lt3'],
#  ['ilivundrurbed', 'anything', 'like', 'every', 'feminist', 'earth'],
#  ['2',
#   'making',
#   'next',
#   'round',
#   'colin',
#   'lost',
#   'credibility',
#   'eyesmkr',
#   'mykitchenrules'],
#  ['mkr',
#   'conclusions',
#   'celine',
#   'legitimately',
#   'hilarious',
#   'rob',
#   'dave',
#   'running',
#   'talladega',
#   'nights',
#   'references',
#   'salmon',
#   'looked',
#   'amazing'],
#  ['thegeek_chick',
#   'already',
#   'typed',
#   'ignorance',
#   'anyone',
#   'understands',
#   'economics',
#   'scroll',
#   'amp',
#   'see',
#   'prove',
#   'thanks'],
#  ['obsurfer84',
#   'babbling',
#   'like',
#   'every',
#   'muslim',
#   'conspiracy',
#   'idiot',
#   'cia',
#   'created',
#   'isisutterly',
#   'stupid',
#   'without',
#   'evidence',
#   'blocked'],
#  ['rt',
#   'ravenhuwolf',
#   'university',
#   'texasarlington',
#   'muslim',
#   'student',
#   'admits',
#   'made',
#   'whole',
#   'story',
#   'httptcocbcr9u4fc9',
#   'httptcoqv'],
#  ['rt',
#   'vonta624',
#   'sexist',
#   'id',
#   'never',
#   'get',
#   'hair',
#   'cut',
#   'women',
#   'like',
#   'racist',
#   'id',
#   'never',
#   'eat',
#   'chicken',
#   'fried',
#   'white',
#   'p'],
#  ['samkitsengupta',
#   'lied',
#   'achieve',
#   'peace',
#   'anything',
#   'built',
#   'lie',
#   'eventually',
#   'fail'],
#  ['rt', 'archangel_dux', 'sexist', 'women', 'cant', 'comedians', 'rappers'],
#  ['ask',
#   'youll',
#   'never',
#   'know',
#   'rapperguydmv',
#   'bruh',
#   'sexist',
#   'wnba',
#   'entertaining'],
#  ['bhamdailynews', 'politics_pr', 'foxnews', 'caved', 'pressure', 'pc'],
#  ['maxblumenthal',
#   'campagnebds',
#   'blumenthal',
#   'doesnt',
#   'report',
#   'anything',
#   'police',
#   'doesnt',
#   'anything'],
#  ['semzyxx',
#   'fact',
#   'many',
#   'different',
#   'hadiths',
#   'say',
#   'six',
#   'married',
#   'contradicted',
#   'directly',
#   'anything'],
#  ['rudawenglish',
#   'daesh',
#   'left',
#   'defend',
#   'turf',
#   'outside',
#   'mosul',
#   'destined',
#   'next',
#   'weeks'],
#  ['tarah',
#   'girlziplocked',
#   'hypatiadotca',
#   'justkelly_ok',
#   'ameliagreenhall',
#   'still',
#   'sellout',
#   'still',
#   'unacceptable',
#   'disgusting'],
#  ['misfitinchains', 'oldgfatherclock', 'venereveritas13', 'santa', 'white'],
#  ['foodie_ben',
#   'may',
#   'like',
#   'replacement',
#   'formula',
#   'book',
#   'allegedly',
#   'recommends',
#   'evans',
#   'go',
#   'mkr'],
#  ['thelindsayellis', 'wnyc', 'listen', 'latest', 'episode', 'explained'],
#  ['killa', 'models', 'give', 'killa', 'dessert', 'mkr'],
#  ['venomous9',
#   'pro',
#   'death',
#   'penalty',
#   'anti',
#   'provisions',
#   'obamacare',
#   'fewer',
#   'govt',
#   'regulations',
#   'free',
#   'market',
#   'better'],
#  ['thought',
#   'meatballs',
#   'going',
#   'win',
#   'peoples',
#   'choice',
#   'brekky',
#   'dish',
#   'coz',
#   'doesnt',
#   'mean',
#   'everyone',
#   'else',
#   'mkr'],
#  ['miss', 'roberts', 'voice', 'mkr'],
#  ['rt',
#   'kmactane',
#   'handles',
#   'wadhwa',
#   'amp',
#   'folks',
#   'claim',
#   'helping',
#   'made',
#   'stopwadhwa2015',
#   'time',
#   'reevaluate',
#   'youre'],
#  ['jihadi_11',
#   'shami_is_back',
#   'filthy',
#   'daesh',
#   'set',
#   'ieds',
#   'baghdad',
#   'dont',
#   'none',
#   'victims',
#   'armedyoure',
#   'hypocrite'],
#  ['go', 'home', 'kat', 'cunt', 'faced', 'bitch', 'mkr', 'httptcoyspbfitztb'],
#  ['rt',
#   'evilsunbro',
#   'women',
#   'r',
#   'pleasing',
#   'look',
#   'upon',
#   'notsexist',
#   'sexhonest'],
#  ['httptcofdylhlkdcv'],
#  ['know',
#   'people',
#   '15',
#   'lipsticks',
#   'purses',
#   'theyre',
#   'great',
#   'accessorizing',
#   'jealous',
#   'lazy',
#   'broke'],
#  ['rt',
#   'sports2inflatio',
#   'lissasauras',
#   'feminism',
#   'supported',
#   'pedophilia',
#   'find',
#   'people',
#   'like',
#   'fighting',
#   'httptcoglncgkuukp'],
#  ['howtogetawaywithmurder', 'serve', 'raw', 'spatchcock', 'mkr', 'mkr2015'],
#  ['muslim',
#   'terrorists',
#   'murder',
#   '12',
#   'people',
#   'paris',
#   '22000',
#   'terrorist',
#   'attacks',
#   'since',
#   '911',
#   'aberration',
#   'real',
#   'islam'],
#  ['rt',
#   'washingtonpost',
#   'dc',
#   'police',
#   'talk',
#   'relisha',
#   'rudd',
#   'info',
#   'call',
#   '2027279099',
#   'httptcom5j2tpksm5',
#   'ht'],
#  ['gbabeuf',
#   'newscoverup',
#   'rjennromao',
#   'davidjo52951945',
#   'novorossiyan',
#   'gbazov',
#   'rougek68',
#   'shit',
#   'room',
#   'talk'],
#  ['fuck',
#   'obviously',
#   'all_hailcaesar',
#   'obviously',
#   'sexist',
#   'got',
#   'tiny',
#   'chuckle',
#   'lol',
#   'httptcopfs5zlkt07'],
#  ['kat', 'andre', 'like', 'worst', 'probably', 'dont', 'friends', 'mkr'],
#  ['damnitscloudy', 'never', 'stop', 'posting', 'wow', 'selfies'],
#  ['proudpatriot101',
#   'right',
#   'side',
#   'muslim',
#   'issue',
#   'wrong',
#   'side',
#   'ukraine',
#   'issue'],
#  ['dont', 'retreat', 'reload'],
#  ['went', 'get', 'breakfast', 'served', 'kat', 'would', 'walk', 'away', 'mkr'],
#  ['mkr',
#   'walk',
#   'steps',
#   'use',
#   'loo',
#   'night',
#   '2',
#   'much',
#   'effort',
#   'sarah_jane666'],
#  ['madasahatter_17',
#   'buttercupashby',
#   'look',
#   'idiotim',
#   'going',
#   'left',
#   'wing',
#   'lunatic',
#   'tell',
#   'tolerate',
#   'islamic',
#   'intolerance'],
#  ['exposefalsehood',
#   'arabthomness',
#   'lol',
#   'couple',
#   'month',
#   'ago',
#   'story',
#   'daesh',
#   'pervious',
#   'air',
#   'strikes'],
#  ['mkr', 'think', 'threw', 'mouth'],
#  ['warriorsialkot',
#   'bilalighumman',
#   'johnnygjokaj',
#   '98halima',
#   'cdnkhadija',
#   'nothing',
#   'isis',
#   'prophet',
#   'mohammed'],
#  ['burcucekmece',
#   'oktar',
#   'blabbers',
#   'ypg',
#   'people',
#   'kobane',
#   'love',
#   'ignoring',
#   'isis',
#   'people',
#   'kobane',
#   'hate',
#   'oktar',
#   'lies'],
#  ['nomcookiesnom',
#   'religions',
#   'statistics',
#   'even',
#   'close',
#   'production',
#   'terrorism'],
#  ['rt',
#   'ivyexec',
#   'know',
#   '4x',
#   'likely',
#   'negotiate',
#   'compensation',
#   'job',
#   'perks',
#   'equalpay'],
#  ['go',
#   'girls',
#   'got',
#   'go',
#   'gueensland',
#   'stop',
#   'mean',
#   'kat',
#   'andre',
#   'mkr'],
#  ['bristolben',
#   'think',
#   'arquette',
#   'dummy',
#   'believes',
#   'valenti',
#   'knowingly',
#   'lies'],
#  ['yum', 'pancakes', 'jac', 'amp', 'shaz', 'look', 'amazing', 'mkr'],
#  ['know',
#   'thats',
#   'interesting',
#   'idea',
#   'maybe',
#   'get',
#   'promoted',
#   'tweets',
#   'ggautoblocker'],
#  ['watched',
#   'mkr',
#   'tonight',
#   'kat',
#   'andre',
#   'disgusted',
#   'uncalled',
#   'many',
#   'levels'],
#  ['really',
#   'concerned',
#   'comes',
#   'gaters',
#   'gatery',
#   'regarding',
#   'org',
#   'thats',
#   'problem'],
#  ['themirai',
#   'sirgoldenrod',
#   'sloshedtrain2',
#   'srhbutts',
#   'tied',
#   'twitter',
#   'user',
#   'ids',
#   'constant',
#   'update',
#   'updates',
#   'run'],
#  ['hope',
#   'kat',
#   'gets',
#   'ebola',
#   'hit',
#   'train',
#   'followed',
#   'smack',
#   'ugly',
#   'shovel',
#   'mkr',
#   'katandandre',
#   'mkrkat'],
#  ['darchmare', 'got', 'worst', 'think', 'easier', 'light'],
#  ['lessons',
#   'gilmore',
#   'girls',
#   'season',
#   '1',
#   'tell',
#   'adult',
#   'youre',
#   'sexually',
#   'harassed',
#   'bullied',
#   'school',
#   'christ'],
#  ['mykitchenrules',
#   'katandandre',
#   'maybe',
#   'make',
#   'sure',
#   'dish',
#   'scratch',
#   'laugh',
#   'others',
#   'nasty',
#   'mkr',
#   'mkr2015'],
#  ['argonblue',
#   'perl',
#   'pretty',
#   'readable',
#   'efficient',
#   'necessarily',
#   'definitely',
#   'possible',
#   'anyone',
#   'read',
#   'amp',
#   'understand'],
#  ['kardashian', 'marriages', 'didnt', 'stretch', 'long', 'mkr'],
#  ['smack',
#   'talk',
#   'period',
#   '__chris33__',
#   'sexist',
#   'hate',
#   'girls',
#   'talk',
#   'sports',
#   'wan',
#   'smackem'],
#  ['edgeofthesandbx',
#   'batchelorshow',
#   'feardept',
#   'dont',
#   'claim',
#   'didnt',
#   'participate',
#   'attrocities',
#   'much',
#   'less',
#   'stalin'],
#  ['girls', 'either', 'hand', 'feet', 'models', 'mkr'],
#  ['glad',
#   'instant',
#   'restaurants',
#   'done',
#   'ive',
#   'missed',
#   'chaos',
#   'mkr',
#   'ilovebreakfast',
#   'andcamping'],
#  ['amohedin',
#   'halalflaws',
#   'haroonstyles',
#   'islamdefense',
#   'greenlinerzjm',
#   'translators',
#   'knew',
#   'arabic',
#   'right'],
#  ['even',
#   'worse',
#   'media',
#   'thinks',
#   'hes',
#   'ally',
#   'keep',
#   'letting',
#   'speak',
#   'us',
#   'stop',
#   'stopwadhwa2015'],
#  ['chuckpfarrer', 'paraketa', 'beautiful', 'map', 'chuck'],
#  ['cooking', 'still', 'shit', 'kat', 'mkr'],
#  ['restaurant', 'tacky', 'mkr'],
#  ['lucaswj',
#   'point',
#   'id',
#   'happy',
#   'wrecking',
#   'faces',
#   'random',
#   'bgs',
#   'havent',
#   'done',
#   'arenas',
#   'months'],
#  ['rt',
#   'akheemv',
#   'bout',
#   'beckles',
#   'another',
#   'woman',
#   'prime',
#   'minister',
#   'sorry',
#   'sexist',
#   'look',
#   'going'],
#  ['discerningmumin',
#   'islam',
#   'pile',
#   'manure',
#   'destroys',
#   'human',
#   'freedom',
#   'human',
#   'life',
#   'human',
#   'expression',
#   'creates',
#   'endless',
#   'divisiveness'],
#  ['rt',
#   'duckiemcphee',
#   'guess',
#   'really',
#   'happened',
#   'mkr',
#   'competition',
#   'running',
#   'eternity'],
#  ['desertfox899', 'referring', 'tim'],
#  ['wouldnt', 'deconstruct', 'lemon', 'tart', 'mkr', 'httptco1pl9gqrdp7'],
#  ['rate', 'going', 'making', 'slides', 'keynote', 'car', 'drive', 'home'],
#  ['tomatoes', 'fine', 'mkr'],
#  ['0xjared',
#   'zython86',
#   'm_m_myers',
#   'chriswarcraft',
#   'started',
#   'naminglisting',
#   'people',
#   'wasnt',
#   'backing'],
#  ['asem_1994',
#   'turks',
#   'conducting',
#   'armenian',
#   'genocide',
#   'last',
#   'century',
#   'question',
#   'get',
#   'beyond',
#   'religious',
#   'hate'],
#  ['blackopal80',
#   'yeah',
#   'eye',
#   'opener',
#   'pay',
#   'gap',
#   'article',
#   'know',
#   'little',
#   'econtried',
#   'explain',
#   'math',
#   'sexism'],
#  ['rt',
#   'sudixitca',
#   'us',
#   'help',
#   'egypt',
#   'provide',
#   'intel',
#   'input',
#   'make',
#   'airstrikes',
#   'success',
#   'really',
#   'dont',
#   'think',
#   'egyptian',
#   'intel',
#   'modern'],
#  ['rt',
#   '_marisajane',
#   'another',
#   'round',
#   'instant',
#   'restaurants',
#   'serious',
#   'mkr',
#   'yawn'],
#  ['rt',
#   'conserv_miss',
#   'idontneedfeminism',
#   'femfreefriday',
#   'httptcopnhzjrhhqr'],
#  ['salon',
#   'themuslimguy',
#   'salon',
#   'tries',
#   'shut',
#   'free',
#   'speech',
#   'shut',
#   'people',
#   'playing',
#   'race',
#   'card',
#   'ideaology',
#   'islam'],
#  ['mechasauce', 'shoe0nhead', 'armpit', 'licking', 'fetish'],
#  ['oh', 'yeah', 'freebsd', 'runs', 'playstations', 'salty'],
#  ['raniakhalek',
#   'maxblumenthal',
#   'another',
#   'taqiyya',
#   'liar',
#   'making',
#   'garbage',
#   'sake',
#   'mohammeds',
#   'desire',
#   'exterminate',
#   'jews'],
#  ['oh',
#   'typo',
#   'guys',
#   'dessert',
#   'get',
#   'sorbent',
#   'youll',
#   'need',
#   'spatchcock',
#   'mkr'],
#  ['glennf', 'quietly', 'helping', 'gators', 'already'],
#  ['owais00',
#   'semzyxx',
#   'nainfidels',
#   'wrong',
#   'microbrain',
#   '6',
#   'like',
#   'prophet',
#   'liar',
#   'proof',
#   'httptcoq95ei17sua'],
#  ['rt',
#   'drdisco_',
#   'love',
#   'judges',
#   'compromise',
#   'values',
#   'channel',
#   '7',
#   'script',
#   'writers',
#   'tell',
#   'credibility',
#   'mkr'],
#  ['years', 'service', 'naga', 'may', 'dying', 'sighhhh'],
#  ['rt',
#   'dreaminpng',
#   'people',
#   'say',
#   'write',
#   'know',
#   'sometimes',
#   'think',
#   'people',
#   'know',
#   'gailsimone',
#   'c2e2'],
#  ['f3ew', 'story', 'behind', 'profile', 'know'],
#  ['yousufpoosuf',
#   'rkinglive2dance',
#   'izrinhariri',
#   'reason',
#   'murdered',
#   'kill',
#   'muslim',
#   'tries'],
#  ['absolutely', 'blondemoment', 'mkr'],
#  ['bit',
#   'luck',
#   'nikki',
#   'promo',
#   'work',
#   'dentist',
#   'get',
#   'free',
#   'whitening',
#   'gel',
#   'mkr'],
#  ['justdavidvideos',
#   'meh',
#   'ive',
#   'seen',
#   'enough',
#   'messed',
#   'stuff',
#   'country',
#   'chances'],
#  ['boys',
#   'ihatethiskid',
#   'sexist',
#   'internet',
#   'show',
#   'girls',
#   'dont',
#   'know',
#   'form',
#   'opinions'],
#  ['rt',
#   'beadsland',
#   'find',
#   'truly',
#   'astounding',
#   'number',
#   'thought',
#   'pieces',
#   'fail',
#   'recognize',
#   'offensive',
#   'segment',
#   'even',
#   'without',
#   'tw'],
#  ['myersnfl', 'oh', 'gosh', 'hope', 'feel', 'better'],
#  ['lemon',
#   'curd',
#   'lemon',
#   'nikki',
#   'powers',
#   'deduction',
#   'even',
#   'amaze',
#   'kids',
#   'short',
#   'bus',
#   'mkr'],
#  ['muslimtwo', 'didazahra', 'mystrongstate', 'raqqa_sl', 'show', 'data'],
#  ['yes', 'yes', 'yes', 'httptcoh8f7n04q5o'],
#  ['thelmasleaze',
#   'fight',
#   'systemic',
#   'problems',
#   'time',
#   'offering',
#   'real',
#   'tips',
#   'protecting',
#   'people',
#   'dont',
#   'time',
#   '2',
#   'wait'],
#  ['curious',
#   'gamergate',
#   'finds',
#   'offensive',
#   'overweight',
#   'completely',
#   'unapologetic',
#   'amp',
#   'unashamed'],
#  ['ldstarr18',
#   'ac360',
#   'many',
#   'ideologies',
#   'islam',
#   'declared',
#   'human',
#   'race',
#   '1400',
#   'years',
#   'ago',
#   'httptcontojwo4lnt'],
#  ['transic_nyc', 'luck', 'shell', 'stylist'],
#  ['lynnemcgranger',
#   'kat',
#   'andre',
#   'disgrace',
#   'booted',
#   'score',
#   'low',
#   'save',
#   'themselvespffft',
#   'mkr'],
#  ['rt',
#   'alihashem_tv',
#   'new',
#   'blow',
#   'islam',
#   'daesh',
#   'burning',
#   'people',
#   'new',
#   'trend',
#   'starting',
#   'next',
#   'castrating',
#   'enemies',
#   'air'],
#  ['someone', 'give', 'kat', 'slap', 'across', 'head', 'mkr', 'bitch'],
#  ['awkward', 'mkr'],
#  ['cant', 'stand', 'kat', 'andre', 'losers', 'mkr'],
#  ['cemcfarland',
#   'quite',
#   'sensitive',
#   'feeling',
#   'previous',
#   'keyboard',
#   'like',
#   'noise',
#   'itll',
#   'problematic',
#   'streaming'],
#  ['refine', 'something', 'deconstructing', 'mkr'],
#  ['rt', 'starius', 'gamergate', 'httpstcoxufwsigxfk', 'win', 'ahahahaha'],
#  ['biebervalue',
#   'greenlinerzjm',
#   'quran',
#   'telling',
#   'beat',
#   'wives',
#   'superior',
#   'httptco8xldnwbvzx'],
#  ['rt',
#   'twista202',
#   'kat',
#   'andre',
#   'absolutely',
#   'nasty',
#   'wanted',
#   'stay',
#   'cooked',
#   'well',
#   'instead',
#   'resorting',
#   'low',
#   'unfair'],
#  ['love',
#   'subtle',
#   'menu',
#   'sausage',
#   'spatchcock',
#   'tart',
#   'perfect',
#   'mkr',
#   'whereisyourdignity'],
#  ['round',
#   'manu',
#   'every',
#   'challenge',
#   'fighting',
#   'negated',
#   'cook',
#   'book',
#   'deal',
#   'court',
#   'mkr'],
#  ['christophheer52',
#   'miskelayla',
#   'pilgars',
#   'repetition',
#   'russian',
#   'propaganda',
#   'line',
#   'ukrainian',
#   'nazis',
#   'insufferable',
#   'lie'],
#  ['mykitchenrules',
#   'bowl',
#   'cornflakes',
#   'wheat',
#   'bixs',
#   'would',
#   'perfect',
#   'mykitchenrules',
#   'hungrycampers',
#   'mkr'],
#  ['rt',
#   'cambrian_man',
#   'freebsdgirl',
#   'culture',
#   'fought',
#   'whether',
#   'harassment',
#   'acceptable'],
#  ['genius',
#   'idea',
#   'trolley',
#   'handle',
#   'aisle',
#   'information',
#   'cup',
#   'holder',
#   'someone',
#   'tell',
#   'paknsave',
#   'lol',
#   'mkr'],
#  ['17',
#   'much',
#   'didnt',
#   'like',
#   'katie',
#   'amp',
#   'nikki',
#   'first',
#   'episode',
#   'ive',
#   'begun',
#   'hate',
#   'kat',
#   'amp',
#   'andre',
#   'much',
#   'last',
#   'week',
#   'mkr'],
#  ['cringing', 'every', 'time', 'see', 'kat', 'amp', 'andre', 'mkr'],
#  ['rt',
#   'hayles_comet',
#   'sexist',
#   'starting',
#   'think',
#   'women',
#   'cant',
#   'drivemaneuveroperate',
#   'anything',
#   '4',
#   'wheels',
#   '800',
#   'lbs'],
#  ['ive',
#   'asked',
#   'stay',
#   'uninvolved',
#   'attacking',
#   'work',
#   'glhf',
#   'youre',
#   'bringing'],
#  ['mkr',
#   'ladies',
#   'manu',
#   'excited',
#   'prospect',
#   'entree',
#   'hes',
#   'excited',
#   'prospect',
#   'going',
#   'home'],
#  ['witch_sniffer',
#   'auntysoapbox',
#   'invented',
#   'dogging',
#   'videos',
#   'cant',
#   'page',
#   '3'],
#  ['bruciebabe',
#   'maxblumenthal',
#   'many',
#   'gulf',
#   'states',
#   'like',
#   'saudi',
#   'zero',
#   'minorities',
#   'left',
#   'due',
#   'islamic',
#   'bigotry',
#   'apartheid'],
#  ['amberhasalamb',
#   'comment',
#   'ford',
#   'thing',
#   'complains',
#   'httptcogbvojnmbcv'],
#  ['neilasaurus',
#   'jimcramer',
#   'thequinnspiracy',
#   'creating',
#   'new',
#   'account',
#   'changing',
#   'username'],
#  ['haroonstyles',
#   'greenlinerzjm',
#   'halalflaws',
#   'biebervalue',
#   'show',
#   'hadith',
#   'get',
#   'information',
#   'waiting']]

# %%
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

text_train_le = []
for tokens in text_train_ns:
  lemma_sentence1 = [lemmatizer.lemmatize(w) for w in tokens ]
  text_train_le.append(lemma_sentence1)

text_test_le = []
for tokens in text_test_ns:
  lemma_sentence2 = [lemmatizer.lemmatize(w) for w in tokens]
  text_test_le.append(lemma_sentence2)
    #Please complete this
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
pprint.pprint(text_train_le[:10])
pprint.pprint(text_test_le[:10])
# Out:
# [['finalbroadcast', 'many', 'dkim', 'setup', 'matter'],
#  ['sevilzadeh',
#   'mohammed',
#   'led',
#   '17',
#   'major',
#   'military',
#   'expedition',
#   'offensive',
#   'raped',
#   'robbed',
#   'murdered',
#   'lied',
#   'slaved',
#   'pedophile'],
#  ['benkuchera', 'saw'],
#  ['realryansipple',
#   'real',
#   'attack',
#   'asad',
#   'would',
#   'yield',
#   'daesh',
#   'killing',
#   'ground',
#   'lot',
#   'open',
#   'space',
#   'civilian',
#   'hide',
#   'behind'],
#  ['someone', 'explain', 'gal', 'sas', 'edible', 'food', 'mkr'],
#  ['rt',
#   'channel7',
#   'british',
#   'lad',
#   'steve',
#   'taking',
#   'mykitchenrules',
#   'instant',
#   'restaurant',
#   'tonight',
#   'theyre',
#   'mkr',
#   'httptco'],
#  ['believe',
#   'two',
#   'fucktards',
#   'still',
#   'competition',
#   'middle',
#   'finger',
#   'say',
#   'hello',
#   'kat',
#   'amp',
#   'andre',
#   'asshole',
#   'mkr'],
#  ['hope',
#   'instant',
#   'restaurant',
#   'round',
#   'good',
#   'getting',
#   'bit',
#   'mkr',
#   'mkr2015'],
#  ['dankmtl',
#   'peacenothate_',
#   'yeah',
#   'keep',
#   'celebrating',
#   'look',
#   'like',
#   'cretin',
#   'httptcotfsodcowbx'],
#  ['lithobolos',
#   'politicalant',
#   'zaibatsunews',
#   'double',
#   'standard',
#   'microbrain',
#   'jew',
#   'christian']]
# [['nelsonempowered', 'false', 'equivalence', 'httptcobilei0l6in'],
#  ['content', 'tweet', 'person', 'sent', 'pref', 'screenshot'],
#  ['discerningmumin',
#   'since',
#   'islam',
#   'declared',
#   'humanity',
#   'humanity',
#   'must',
#   'return',
#   'favor',
#   'declare',
#   'islam'],
#  ['heathermoandco',
#   'lostsailorny',
#   'shermertron',
#   'please',
#   'explain',
#   '77',
#   'figure',
#   'cited',
#   'wage',
#   'gap',
#   'discussion',
#   'compare',
#   'thanks'],
#  ['rt',
#   'rbpundit',
#   'scott',
#   'walker',
#   'troll',
#   'left',
#   'get',
#   'online',
#   'degree',
#   'gender',
#   'study'],
#  ['0xabad1dea'],
#  ['twitter',
#   'dont',
#   'know',
#   'talking',
#   'oh',
#   'woman',
#   'couldnt',
#   'software',
#   'dev',
#   'oh',
#   'lordy'],
#  ['kat',
#   'repeat',
#   'unbridled',
#   'joy',
#   'annie',
#   'failing',
#   'towards',
#   'failure',
#   'mkr'],
#  ['surprised',
#   'instant',
#   'restaurant',
#   'look',
#   'like',
#   'playboy',
#   'mansion',
#   'class',
#   'girl',
#   'class',
#   'none',
#   'mkr'],
#  ['think',
#   'manu',
#   'sos',
#   'addiction',
#   'someone',
#   'need',
#   'hold',
#   'intervention',
#   'mkr']]

# %%
import numpy as np

from sklearn.preprocessing import LabelEncoder

unique_labels = np.unique(label_train)

lEnc = LabelEncoder()
# Please encode the labels (Do NOT add new lines of code in this section)
# Hint: Try to understand the difference between fit_transform and transform
label_train_encoded = lEnc.fit_transform(label_train)
label_test_encoded = lEnc.fit_transform(label_test)

n_class = len(unique_labels)
print(unique_labels)
print(lEnc.transform(unique_labels))
# Out:
# ['none' 'racism' 'sexism']
# [0 1 2]

# %%
word_set = set() 
for sent in text_train_le:
    for word in sent:
        word_set.add(word)
word_set.add('[PAD]')
word_set.add('[UNKNOWN]')

word_list = list(word_set) 
word_list.sort()
print(word_list)

word_index = {}
ind = 0
for word in word_list:
    word_index[word] = ind
    ind += 1
print(word_index)
# Out:
# ['0', '06jank', '0xjared', '1', '11', '12', '14', '1400', '15', '17', '1shadeofritch', '2', '2027279099', '22000', '2ndbestidiot', '3', '3outof10', '4', '44', '47', '4x', '5', '6', '7', '80', '800', '90', '911', '98halima', '99', '[PAD]', '[UNKNOWN]', '__chris33__', '_marisajane', 'abducted', 'abdul_a95', 'aberration', 'ability', 'ablahad', 'able', 'absolutely', 'abuse', 'ac360', 'accept', 'acceptable', 'accepted', 'accessorizing', 'account', 'achieve', 'across', 'actoractress', 'actually', 'adjective', 'admits', 'adult', 'afar', 'afraid', 'ago', 'agree', 'ahahahaha', 'air', 'airstrikes', 'aisle', 'ajwatamr', 'akheemv', 'aledthomas22', 'alihadi68', 'alihashem_tv', 'alive', 'all_hailcaesar', 'allegedly', 'allstatejackie', 'ally', 'along', 'already', 'alternet', 'amaze', 'amazing', 'amazingly', 'amberhasalamb', 'ameliagreenhall', 'american', 'amohedin', 'amp', 'amymek', 'anasmechch', 'andcamping', 'andre', 'angelemichelle', 'anitaingle', 'annoying', 'another', 'answer', 'anti', 'antiharassment', 'antizholim', 'anyone', 'anything', 'apartheid', 'arab_fury', 'arabic', 'arabthomness', 'archangel_dux', 'arena', 'argh', 'argonblue', 'argument', 'armedyoure', 'armenian', 'armpit', 'army', 'arquette', 'article', 'asad', 'asem_1994', 'ask', 'asked', 'askgoog', 'askhermore', 'asshole', 'astounding', 'athlete', 'attack', 'attacked', 'attacking', 'attracted', 'attractive', 'attributing', 'attrocities', 'auntysoapbox', 'australia', 'away', 'awful', 'awkward', 'awww', 'b', 'babbling', 'back', 'backing', 'backwards', 'bad', 'bag', 'baghdad', 'bahai144', 'bamboozled', 'banter', 'barackobama', 'basically', 'bastendorfgames', 'batchelorshow', 'bcz', 'beadsland', 'beat', 'beautiful', 'beautifula', 'beavis', 'beckles', 'begun', 'behaving', 'behead', 'behind', 'belief', 'believe', 'benkuchera', 'best', 'better', 'beyond', 'bgs', 'bhamdailynews', 'biebervalue', 'big', 'bigot', 'bigotry', 'bigtime', 'bilalighumman', 'bill', 'bimbo', 'bimbolines', 'bit', 'bitch', 'bixs', 'blabber', 'blackopal80', 'block', 'blocked', 'bloke', 'blonde', 'blondemoment', 'blow', 'blumenthal', 'body', 'book', 'booted', 'boring', 'bos', 'bottle', 'bought', 'bout', 'bowl', 'boy', 'bq281473', 'breakfast', 'brekky', 'bringing', 'bristolben', 'british', 'broke', 'bronny25', 'bruciebabe', 'bruh', 'brushyblues', 'bsilverstrim77', 'budlightbro', 'built', 'bullied', 'burcucekmece', 'burn', 'burning', 'burqua', 'bus', 'business', 'buttercupashby', 'butthead', 'button', 'buying', 'c2e2', 'call', 'cambrian_man', 'campagnebds', 'canned', 'cant', 'captive', 'car', 'card', 'case', 'cashing', 'castrating', 'catwalk', 'cause', 'caved', 'ccot', 'cdnkhadija', 'celebrating', 'celine', 'cemcfarland', 'century', 'challenge', 'chance', 'change', 'changed', 'changing', 'channel', 'channel7', 'chaos', 'character', 'cheeseplus', 'chef', 'cheney', 'chicken', 'child', 'chloeandkelly', 'choice', 'christ', 'christian', 'christiansyazidis', 'christmas', 'christophheer52', 'chriswarcraft', 'chuck', 'chuckle', 'chuckpfarrer', 'churner', 'cia', 'cityofmandurah', 'civilian', 'cjsajulga', 'claim', 'claiming', 'clarify', 'clearly', 'close', 'colin', 'colins', 'colonelkickhead', 'come', 'comedian', 'coming', 'comment', 'committed', 'compensation', 'competition', 'complains', 'completely', 'compromise', 'concerned', 'conclusion', 'conducting', 'configuration', 'confuse', 'conserv_miss', 'consider', 'conspiracy', 'constant', 'constantly', 'constructed', 'content', 'contradicted', 'contributing', 'cook', 'cooked', 'cooking', 'cordial', 'cornflakes', 'could', 'country', 'couple', 'court', 'coworkers', 'coz', 'crabfest15', 'crap', 'crash', 'created', 'creates', 'creating', 'credibility', 'cretin', 'cringing', 'critiquing', 'culture', 'cunt', 'cup', 'curd', 'curious', 'customer', 'cut', 'cuz', 'cytheria', 'd20', 'daesh', 'damn', 'damnitscloudy', 'danhickey2199', 'danis', 'dankmtl', 'darchmare', 'darrenkopp', 'data', 'dave', 'davidjo52951945', 'davidsgallant', 'dc', 'dead', 'deal', 'death', 'declared', 'deconstruct', ...
# {'0': 0, '06jank': 1, '0xjared': 2, '1': 3, '11': 4, '12': 5, '14': 6, '1400': 7, '15': 8, '17': 9, '1shadeofritch': 10, '2': 11, '2027279099': 12, '22000': 13, '2ndbestidiot': 14, '3': 15, '3outof10': 16, '4': 17, '44': 18, '47': 19, '4x': 20, '5': 21, '6': 22, '7': 23, '80': 24, '800': 25, '90': 26, '911': 27, '98halima': 28, '99': 29, '[PAD]': 30, '[UNKNOWN]': 31, '__chris33__': 32, '_marisajane': 33, 'abducted': 34, 'abdul_a95': 35, 'aberration': 36, 'ability': 37, 'ablahad': 38, 'able': 39, 'absolutely': 40, 'abuse': 41, 'ac360': 42, 'accept': 43, 'acceptable': 44, 'accepted': 45, 'accessorizing': 46, 'account': 47, 'achieve': 48, 'across': 49, 'actoractress': 50, 'actually': 51, 'adjective': 52, 'admits': 53, 'adult': 54, 'afar': 55, 'afraid': 56, 'ago': 57, 'agree': 58, 'ahahahaha': 59, 'air': 60, 'airstrikes': 61, 'aisle': 62, 'ajwatamr': 63, 'akheemv': 64, 'aledthomas22': 65, 'alihadi68': 66, 'alihashem_tv': 67, 'alive': 68, 'all_hailcaesar': 69, 'allegedly': 70, 'allstatejackie': 71, 'ally': 72, 'along': 73, 'already': 74, 'alternet': 75, 'amaze': 76, 'amazing': 77, 'amazingly': 78, 'amberhasalamb': 79, 'ameliagreenhall': 80, 'american': 81, 'amohedin': 82, 'amp': 83, 'amymek': 84, 'anasmechch': 85, 'andcamping': 86, 'andre': 87, 'angelemichelle': 88, 'anitaingle': 89, 'annoying': 90, 'another': 91, 'answer': 92, 'anti': 93, 'antiharassment': 94, 'antizholim': 95, 'anyone': 96, 'anything': 97, 'apartheid': 98, 'arab_fury': 99, 'arabic': 100, 'arabthomness': 101, 'archangel_dux': 102, 'arena': 103, 'argh': 104, 'argonblue': 105, 'argument': 106, 'armedyoure': 107, 'armenian': 108, 'armpit': 109, 'army': 110, 'arquette': 111, 'article': 112, 'asad': 113, 'asem_1994': 114, 'ask': 115, 'asked': 116, 'askgoog': 117, 'askhermore': 118, 'asshole': 119, 'astounding': 120, 'athlete': 121, 'attack': 122, 'attacked': 123, 'attacking': 124, 'attracted': 125, 'attractive': 126, 'attributing': 127, 'attrocities': 128, 'auntysoapbox': 129, 'australia': 130, 'away': 131, 'awful': 132, 'awkward': 133, 'awww': 134, 'b': 135, 'babbling': 136, 'back': 137, 'backing': 138, 'backwards': 139, 'bad': 140, 'bag': 141, 'baghdad': 142, 'bahai144': 143, 'bamboozled': 144, 'banter': 145, 'barackobama': 146, 'basically': 147, 'bastendorfgames': 148, 'batchelorshow': 149, 'bcz': 150, 'beadsland': 151, 'beat': 152, 'beautiful': 153, 'beautifula': 154, 'beavis': 155, 'beckles': 156, 'begun': 157, 'behaving': 158, 'behead': 159, 'behind': 160, 'belief': 161, 'believe': 162, 'benkuchera': 163, 'best': 164, 'better': 165, 'beyond': 166, 'bgs': 167, 'bhamdailynews': 168, 'biebervalue': 169, 'big': 170, 'bigot': 171, 'bigotry': 172, 'bigtime': 173, 'bilalighumman': 174, 'bill': 175, 'bimbo': 176, 'bimbolines': 177, 'bit': 178, 'bitch': 179, 'bixs': 180, 'blabber': 181, 'blackopal80': 182, 'block': 183, 'blocked': 184, 'bloke': 185, 'blonde': 186, 'blondemoment': 187, 'blow': 188, 'blumenthal': 189, 'body': 190, 'book': 191, 'booted': 192, 'boring': 193, 'bos': 194, 'bottle': 195, 'bought': 196, 'bout': 197, 'bowl': 198, 'boy': 199, 'bq281473': 200, 'breakfast': 201, 'brekky': 202, 'bringing': 203, 'bristolben': 204, 'british': 205, 'broke': 206, 'bronny25': 207, 'bruciebabe': 208, 'bruh': 209, 'brushyblues': 210, 'bsilverstrim77': 211, 'budlightbro': 212, 'built': 213, 'bullied': 214, 'burcucekmece': 215, 'burn': 216, 'burning': 217, 'burqua': 218, 'bus': 219, 'business': 220, 'buttercupashby': 221, 'butthead': 222, 'button': 223, 'buying': 224, 'c2e2': 225, 'call': 226, 'cambrian_man': 227, 'campagnebds': 228, 'canned': 229, 'cant': 230, 'captive': 231, 'car': 232, 'card': 233, 'case': 234, 'cashing': 235, 'castrating': 236, 'catwalk': 237, 'cause': 238, 'caved': 239, 'ccot': 240, 'cdnkhadija': 241, 'celebrating': 242, 'celine': 243, 'cemcfarland': 244, 'century': 245, 'challenge': 246, 'chance': 247, 'change': 248, 'changed': 249, 'changing': 250, 'channel': 251, 'channel7': 252, 'chaos': 253, 'character': 254, 'cheeseplus': 255, 'chef': 256, 'cheney': ...

# %%
'''
word_set = set() 
for sent in text_test_le:
    for word in sent:
        word_set.add(word)
word_set.add('[PAD]')
word_set.add('[UNKNOWN]')

word_list = list(word_set) 
word_list.sort()
print(word_list)

word_index2 = {}
ind = 0
for word in word_list:
    word_index2[word] = ind
    ind += 1
print(word_index2)
'''
# Out:
# "\nword_set = set() \nfor sent in text_test_le:\n    for word in sent:\n        word_set.add(word)\nword_set.add('[PAD]')\nword_set.add('[UNKNOWN]')\n\nword_list = list(word_set) \nword_list.sort()\nprint(word_list)\n\nword_index2 = {}\nind = 0\nfor word in word_list:\n    word_index2[word] = ind\n    ind += 1\nprint(word_index2)\n"

# %% [markdown]
# #之前都没问题了

# %%
if word not in word_index:
        temp_encoded = [word_index.get(i,word_index['[UNKNOWN]']) for i in sent]

# %%
# The sequence length is pre-defined, you can't change this value for this exercise
seq_length = 16

# Please Complete this function
# Hint: You should pay attention to: (1) if the sentence length > seq_length (2) if the word not in word_index dictionary
def encode_and_add_padding(sentences, seq_length, word_index):
    sent_encoded = []
    
    for sent in sentences: 
      temp_encoded = [word_index[word] for word in sent]
      if len(temp_encoded) < seq_length:
        temp_encoded += [word_index['[PAD]']] * (seq_length - len(temp_encoded))  #30
      elif len(temp_encoded) > seq_length:
        temp_encoded = temp_encoded[:16]
      sent_encoded.append(temp_encoded)

    return sent_encoded

train_pad_encoded = encode_and_add_padding(text_train_le, seq_length, word_index )
test_pad_encoded = encode_and_add_padding(text_test_le, seq_length, word_index )  #100 16
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-49cf5f13c0a7> in <module>()
#      19
#      20 train_pad_encoded = encode_and_add_padding(text_train_le, seq_length, word_index )
# ---> 21 test_pad_encoded = encode_and_add_padding(text_test_le, seq_length, word_index )  #100 16
#
# <ipython-input-15-49cf5f13c0a7> in encode_and_add_padding(sentences, seq_length, word_index)
#       9
#      10     for sent in sentences:
# ---> 11       temp_encoded = [word_index[word] for word in sent]
#      12       if len(temp_encoded) < seq_length:
#      13         temp_encoded += [word_index['[PAD]']] * (seq_length - len(temp_encoded))  #30
#
# <ipython-input-15-49cf5f13c0a7> in <listcomp>(.0)
#       9
#      10     for sent in sentences:
# ---> 11       temp_encoded = [word_index[word] for word in sent]
#      12       if len(temp_encoded) < seq_length:
#      13         temp_encoded += [word_index['[PAD]']] * (seq_length - len(temp_encoded))  #30
#
# KeyError: 'nelsonempowered'

# %%
# The sequence length is pre-defined, you can't change this value for this exercise
seq_length = 16

# Please Complete this function
# Hint: You should pay attention to: (1) if the sentence length > seq_length (2) if the word not in word_index dictionary
def encode_and_add_padding(sentences, seq_length, word_index):
    sent_encoded = []
    for sent in sentences: 
      if word not in sent:
        temp_encoded = [word_index.get(i,word_index['[UNKNOWN]']) for i in]
        
      else:
        temp_encoded = [word_index[word] for word in sent]
        if len(temp_encoded) < seq_length:
          temp_encoded += [word_index['[PAD]']] * (seq_length - len(temp_encoded))  #30
        elif len(temp_encoded) > seq_length:
          temp_encoded = temp_encoded[:16]
      sent_encoded.append(temp_encoded)

    return sent_encoded

train_pad_encoded = encode_and_add_padding(text_train_le, seq_length, word_index )
test_pad_encoded = encode_and_add_padding(text_test_le, seq_length, word_index )  #100 16

# %%
pprint.pprint(train_pad_encoded[:10])
pprint.pprint(test_pad_encoded[:10])

# %%
import gensim.downloader as api
word_emb_model = api.load("glove-twitter-50") # Download an embedding other than glove-twitter-25

# %%
# Get the Embedding lookup table
import numpy as np
emb_dim = word_emb_model.vector_size

emb_table = []
for i, word in enumerate(word_list):
    if word in word_emb_model:
        emb_table.append(word_emb_model[word])
    else:
        emb_table.append([0]*emb_dim)
emb_table = np.array(emb_table)

# %%
vocab_size = len(word_list)
n_hidden = 50
total_epoch = 100
learning_rate = 0.01

# %%
import torch
#You can enable GPU here (cuda); or just CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import numpy as np

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import accuracy_score

class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.emb = nn.Embedding(vocab_size, emb_dim)
        self.emb.weight.data.copy_(torch.from_numpy(emb_table))
        self.emb.weight.requires_grad = False
        self.lstm = nn.LSTM(emb_dim, n_hidden, num_layers=2, batch_first =True, dropout=0.2)
        self.linear = nn.Linear(n_hidden,n_class)

    def forward(self, x):
        x = self.emb(x)
        x,_ = self.lstm(x)
        x = self.linear(x[:,-1,:])
        return x


model = Model().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

input_torch = torch.from_numpy(np.array(train_pad_encoded)).to(device)
target_torch = torch.from_numpy(np.array(label_train_encoded)).view(-1).to(device)

print(input_torch)

for epoch in range(total_epoch):  
    
    model.train()
    optimizer.zero_grad()
    outputs = model(input_torch) 
    loss = criterion(outputs, target_torch) #[1,3][300]
    loss.backward()
    optimizer.step()
    
    if epoch%10 == 9:
        predicted = torch.argmax(outputs, -1)
        acc= accuracy_score(predicted.cpu().numpy(),target_torch.cpu().numpy())

        print('Epoch: %d, loss: %.5f, train_acc: %.2f' %(epoch + 1, loss.item(), acc))

print('Finished Training')

# %% [markdown]
# **Save the model [Complete this part]**

# %%
torch.save(model,'lab5.pt')

# %%
model2 = torch.load('lab5.pt')
model2.eval()

# %%
input_torch = torch.from_numpy(np.array(test_pad_encoded)).to(device)

outputs = model2(input_torch) 
predicted = torch.argmax(outputs, -1)

from sklearn.metrics import classification_report
print(classification_report(label_test_encoded,predicted.cpu().numpy()))
